# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv("../data/EDD_table_v44+.csv")

# %%
data[:10]
# Out:
#      PGC                                 Name       RA       DE     GLong  \
# 0  13418                            NGC1399    54.6212 -35.4506  236.7163
# 1  13179                            NGC1365    53.4016 -36.1405  237.9564
# 2  13433                            NGC1404    54.7163 -35.5942  236.9551
# 3  13318                            NGC1380    54.1149 -34.9761  235.9261
# 4  13344                            NGC1387    54.2377 -35.5066  236.8246
# 5  13059                            NGC1350    52.7837 -33.6284  233.6122
# 6  13333                            NGC1386    54.1925 -35.9992  237.6634
# 7  13267                            NGC1374    53.8191 -35.2263  236.3623
# 8  13609                            NGC1427    55.5808 -35.3928  236.5971
# 9  13299                            NGC1379    54.0159 -35.4412  236.7220
#
#       GLat       SGL      SGB      Ty      B_t    ...      gVls  gND       gD  \
# ...

# %%
a= plt.hist(data['lgL_K'], bins=np.arange(8.0, 12.0, 0.20))
